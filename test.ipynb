# %%
import pandas as pd

# %%
props = pd.read_csv('http://www.firstpythonnotebook.org/_static/committees.csv')
contribs = pd.read_csv('http://www.firstpythonnotebook.org/_static/contributions.csv')

# %%
props.head(2)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT

# %%
contribs.head(2)
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# 1                 MYRNA        SAN DIEGO                CA           92109
#
#        contributor_employer contributor_occupation  \
# 0                A NEW PATH     EXECUTIVE DIRECTOR
# 1  NATIONAL SCHOOL DISTRICT                TEACHER
#
#    contributor_is_self_employed  amount
# 0                         False    84.0
# 1                         False    35.0

# %%
merged = pd.merge(props, contribs, on ='calaccess_committee_id')

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props_066 = merged[merged.prop_name == 'PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.']

# %%
props_066.head(3)
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1808  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 1809  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 1810  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#       ccdc_prop_id                                          prop_name  \
# 1808            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 1809            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 1810            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
#
#       ccdc_committee_id  calaccess_committee_id  \
# 1808                471                 1386494
# 1809                471                 1386494
# 1810                471                 1386494
#
#                                        committee_name_x committee_position  \
# 1808  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...             OPPOSE
# ...

# %%
props_066.committee_position.value_counts()
# Out:
# SUPPORT    29633
# OPPOSE      4195
# Name: committee_position, dtype: int64

# %%
support_066 = props_066[props_066.committee_position == 'SUPPORT']

# %%
oppose_066 = props_066[props_066.committee_position == 'OPPOSE']

# %%
support_066.sort_values('amount', ascending = False).head(3)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 70828  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 70596  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 71316  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#        ccdc_prop_id                                          prop_name  \
# 70828            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 70596            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 71316            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
#
#        ccdc_committee_id  calaccess_committee_id  \
# 70828                468                 1346266
# 70596                468                 1346266
# 71316                468                 1346266
#
#                                         committee_name_x committee_position  \
# 70828  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...            SUPPORT
# ...

# %%
oppose_066.sort_values('amount', ascending = False).head(3)
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 2113  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 1924  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 2114  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#       ccdc_prop_id                                          prop_name  \
# 2113            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 1924            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 2114            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
#
#       ccdc_committee_id  calaccess_committee_id  \
# 2113                470                 1385745
# 1924                473                 1391170
# 2114                470                 1385745
#
#                                        committee_name_x committee_position  \
# 2113       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))             OPPOSE
# ...
